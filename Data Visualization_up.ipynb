# %%
#General libraries

import numpy as np
import pandas as pd

#Visualization libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "D:\programming project feb 2024\Spain Energy Dataset\df_electricity_cleaned.csv"
#Reading our Dataset
df_viz=pd.read_csv(path)
#Showing first five values from the dataset
df_viz.head()
# Out:
#                         time  generation_biomass  \
# 0  2015-01-01 00:00:00+01:00               447.0
# 1  2015-01-01 01:00:00+01:00               449.0
# 2  2015-01-01 02:00:00+01:00               448.0
# 3  2015-01-01 03:00:00+01:00               438.0
# 4  2015-01-01 04:00:00+01:00               428.0
#
#    generation_fossil_brown_coal_lignite  generation_fossil_gas  \
# 0                                 329.0                 4844.0
# 1                                 328.0                 5196.0
# 2                                 323.0                 4857.0
# 3                                 254.0                 4314.0
# 4                                 187.0                 4130.0
#
#    generation_fossil_hard_coal  generation_fossil_oil  \
# 0                       4821.0                  162.0
# 1                       4755.0                  158.0
# 2                       4581.0                  157.0
# 3                       4131.0                  160.0
# 4                       3840.0                  156.0
#
#    generation_hydro_pumped_storage_consumption  \
# 0                                        863.0
# 1                                        920.0
# 2                                       1164.0
# 3                                       1503.0
# 4                                       1826.0
#
#    generation_hydro_run-of-river_and_poundage  \
# 0                                      1051.0
# 1                                      1009.0
# 2                                       973.0
# 3                                       949.0
# 4                                       953.0
#
#    generation_hydro_water_reservoir  generation_nuclear  generation_other  \
# 0                            1899.0              7096.0              43.0
# 1                            1658.0              7096.0              43.0
# 2                            1371.0              7099.0              43.0
# 3                             779.0              7098.0              43.0
# 4                             720.0              7097.0              43.0
#
#    generation_other_renewable  generation_solar  generation_waste  \
# 0                        73.0              49.0             196.0
# 1                        71.0              50.0             195.0
# 2                        73.0              50.0             196.0
# 3                        75.0              50.0             191.0
# 4                        74.0              42.0             189.0
#
#    generation_wind_onshore  total_load_actual  price_day_ahead  price_actual
# 0                   6378.0            25385.0            50.10         65.41
# 1                   5890.0            24382.0            48.10         64.92
# 2                   5461.0            22734.0            47.33         64.48
# 3                   5238.0            21286.0            42.27         59.32
# 4                   4935.0            20264.0            38.41         56.04

# %%
# Correlation of columns to target variable 
correlations=df_viz.drop(['time'],axis=1)
correlations1 = correlations.corr(method='pearson')
correlations1
# Out:
#                                              generation_biomass  \
# generation_biomass                                     1.000000
# generation_fossil_brown_coal_lignite                   0.230034
# generation_fossil_gas                                 -0.021522
# generation_fossil_hard_coal                            0.433733
# generation_fossil_oil                                  0.459588
# generation_hydro_pumped_storage_consumption           -0.045055
# generation_hydro_run-of-river_and_poundage            -0.284648
# generation_hydro_water_reservoir                      -0.033352
# generation_nuclear                                    -0.021065
# generation_other                                       0.658392
# generation_other_renewable                            -0.560600
# generation_solar                                      -0.004746
# generation_waste                                      -0.346073
# generation_wind_onshore                               -0.068688
# total_load_actual                                      0.083438
# price_day_ahead                                        0.109236
# price_actual                                           0.142688
#
#                                              generation_fossil_brown_coal_lignite  \
# generation_biomass                                                       0.230034
# generation_fossil_brown_coal_lignite                                     1.000000
# generation_fossil_gas                                                    0.499899
# generation_fossil_hard_coal                                              0.768819
# generation_fossil_oil                                                    0.314885
# generation_hydro_pumped_storage_consumption                             -0.324024
# generation_hydro_run-of-river_and_poundage                              -0.524707
# generation_hydro_water_reservoir                                        -0.228906
# generation_nuclear                                                      -0.007578
# generation_other                                                         0.097981
# generation_other_renewable                                               0.104386
# generation_solar                                                         0.040033
# generation_waste                                                         0.282888
# generation_wind_onshore                                                 -0.434212
# total_load_actual                                                        0.280729
# price_day_ahead                                                          0.568156
# price_actual                                                             0.363986
#
#                                              generation_fossil_gas  \
# generation_biomass                                       -0.021522
# generation_fossil_brown_coal_lignite                      0.499899
# generation_fossil_gas                                     1.000000
# generation_fossil_hard_coal                               0.541687
# generation_fossil_oil                                     0.309545
# generation_hydro_pumped_storage_consumption              -0.420747
# generation_hydro_run-of-river_and_poundage               -0.271495
# generation_hydro_water_reservoir                          0.060344
# generation_nuclear                                       -0.112268
# generation_other                                         -0.065987
# generation_other_renewable                                0.334827
# generation_solar                                          0.074464
# generation_waste                                          0.275167
# generation_wind_onshore                                  -0.397335
# total_load_actual                                         0.548990
# price_day_ahead                                           0.640891
# price_actual                                              0.461423
#
#                                              generation_fossil_hard_coal  \
# generation_biomass                                              0.433733
# generation_fossil_brown_coal_lignite                            0.768819
# generation_fossil_gas                                           0.541687
# generation_fossil_hard_coal                                     1.000000
# generation_fossil_oil                                           0.440851
# generation_hydro_pumped_storage_consumption                    -0.406298
# generation_hydro_run-of-river_and_poundage                     -0.497573
# generation_hydro_water_reservoir                               -0.157093
# generation_nuclear                                             -0.023168
# generation_other                                                0.264624
# generation_other_renewable                                     -0.019593
# generation_solar                                                0.045870
# generation_waste                                                0.170264
# generation_wind_onshore                                        -0.441781
# total_load_actual                                               0.396947
# price_day_ahead                                                 0.671779
# price_actual                                                    0.465648
#
#                                              generation_fossil_oil  \
# generation_biomass                                        0.459588
# generation_fossil_brown_coal_lignite                      0.314885
# generation_fossil_gas                                     0.309545
# generation_fossil_hard_coal                               0.440851
# generation_fossil_oil                                     1.000000
# generation_hydro_pumped_storage_consumption              -0.330967
# generation_hydro_run-of-river_and_poundage               -0.106458
# generation_hydro_water_reservoir                          0.160700
# generation_nuclear                                        0.015430
# generation_other                                          0.374773
# generation_other_renewable                               -0.115386
# generation_solar                                          0.100213
# generation_waste                                         -0.176109
# generation_wind_onshore                                  -0.051755
# total_load_actual                                         0.496173
# price_day_ahead                                           0.292831
# price_actual                                              0.285021
#
#                                              generation_hydro_pumped_storage_consumption  \
# generation_biomass                                                             -0.045055
# generation_fossil_brown_coal_lignite                                           -0.324024
# generation_fossil_gas                                                          -0.420747
# generation_fossil_hard_coal                                                    -0.406298
# generation_fossil_oil                                                          -0.330967
# generation_hydro_pumped_storage_consumption                                     1.000000
# generation_hydro_run-of-river_and_poundage                                      0.053197
# generation_hydro_water_reservoir                                               -0.234451
# generation_nuclear                                                              0.012494
# generation_other                                                                0.021258
# generation_other_renewable                                                     -0.267355
# generation_solar                                                               -0.214355
# generation_waste                                                               -0.188288
# generation_wind_onshore                                                         0.389139
# total_load_actual                                                              -0.562769
# price_day_ahead                                                                -0.600553
# price_actual                                                                   -0.426211
#
#                                              generation_hydro_run-of-river_and_poundage  \
# generation_biomass                                                            -0.284648
# generation_fossil_brown_coal_lignite                                          -0.524707
# generation_fossil_gas                                                         -0.271495
# generation_fossil_hard_coal                                                   -0.497573
# generation_fossil_oil                                                         -0.106458
# generation_hydro_pumped_storage_consumption                                    0.053197
# generation_hydro_run-of-river_and_poundage                                     1.000000
# generation_hydro_water_reservoir                                               0.652724
# generation_nuclear                                                            -0.124114
# generation_other                                                              -0.127353
# generation_other_renewable                                                     0.053214
# generation_solar                                                               0.039655
# generation_waste                                                              -0.286303
# generation_wind_onshore                                                        0.223203
# total_load_actual                                                              0.118340
# price_day_ahead                                                               -0.294518
# price_actual                                                                  -0.136657
#
#                                              generation_hydro_water_reservoir  \
# generation_biomass                                                  -0.033352
# generation_fossil_brown_coal_lignite                                -0.228906
# generation_fossil_gas                                                0.060344
# generation_fossil_hard_coal                                         -0.157093
# generation_fossil_oil                                                0.160700
# generation_hydro_pumped_storage_consumption                         -0.234451
# generation_hydro_run-of-river_and_poundage                           0.652724
# generation_hydro_water_reservoir                                     1.000000
# generation_nuclear                                                  -0.049216
# generation_other                                                     0.065300
# generation_other_renewable                                          -0.065920
# generation_solar                                                     0.091686
# generation_waste                                                    -0.288154
# generation_wind_onshore                                             -0.019419
# total_load_actual                                                    0.479253
# price_day_ahead                                                     -0.017423
# price_actual                                                         0.071830
#
#                                              generation_nuclear  \
# generation_biomass                                    -0.021065
# generation_fossil_brown_coal_lignite                  -0.007578
# generation_fossil_gas                                 -0.112268
# generation_fossil_hard_coal                           -0.023168
# generation_fossil_oil                                  0.015430
# generation_hydro_pumped_storage_consumption            0.012494
# generation_hydro_run-of-river_and_poundage            -0.124114
# generation_hydro_water_reservoir                      -0.049216
# generation_nuclear                                     1.000000
# generation_other                                       0.041723
# generation_other_renewable                            -0.062053
# generation_solar                                       0.003860
# generation_waste                                       0.087578
# generation_wind_onshore                                0.048472
# total_load_actual                                      0.085803
# price_day_ahead                                       -0.043348
# price_actual                                          -0.052981
#
#                                              generation_other  \
# generation_biomass                                   0.658392
# generation_fossil_brown_coal_lignite                 0.097981
# generation_fossil_gas                               -0.065987
# generation_fossil_hard_coal                          0.264624
# generation_fossil_oil                                0.374773
# generation_hydro_pumped_storage_consumption          0.021258
# generation_hydro_run-of-river_and_poundage          -0.127353
# generation_hydro_water_reservoir                     0.065300
# generation_nuclear                                   0.041723
# generation_other                                     1.000000
# generation_other_renewable                          -0.443450
# generation_solar                                    -0.016822
# generation_waste                                    -0.359655
# generation_wind_onshore                              0.047374
# total_load_actual                                    0.100768
# price_day_ahead                                      0.043971
# price_actual                                         0.099875
#
#                                              generation_other_renewable  \
# generation_biomass                                            -0.560600
# generation_fossil_brown_coal_lignite                           0.104386
# generation_fossil_gas                                          0.334827
# generation_fossil_hard_coal                                   -0.019593
# generation_fossil_oil                                         -0.115386
# generation_hydro_pumped_storage_consumption                   -0.267355
# generation_hydro_run-of-river_and_poundage                     0.053214
# generation_hydro_water_reservoir                              -0.065920
# generation_nuclear                                            -0.062053
# generation_other                                              -0.443450
# generation_other_renewable                                     1.000000
# generation_solar                                               0.025682
# generation_waste                                               0.613987
# generation_wind_onshore                                       -0.138286
# total_load_actual                                              0.180955
# price_day_ahead                                                0.427784
# price_actual                                                   0.255544
#
#                                              generation_solar  \
# generation_biomass                                  -0.004746
# generation_fossil_brown_coal_lignite                 0.040033
# generation_fossil_gas                                0.074464
# generation_fossil_hard_coal                          0.045870
# generation_fossil_oil                                0.100213
# generation_hydro_pumped_storage_consumption         -0.214355
# generation_hydro_run-of-river_and_poundage           0.039655
# generation_hydro_water_reservoir                     0.091686
# generation_nuclear                                   0.003860
# generation_other                                    -0.016822
# generation_other_renewable                           0.025682
# generation_solar                                     1.000000
# generation_waste                                     0.000629
# generation_wind_onshore                             -0.166606
# total_load_actual                                    0.395609
# price_day_ahead                                      0.058049
# price_actual                                         0.098530
#
#                                              generation_waste  \
# generation_biomass                                  -0.346073
# generation_fossil_brown_coal_lignite                 0.282888
# generation_fossil_gas                                0.275167
# generation_fossil_hard_coal                          0.170264
# generation_fossil_oil                               -0.176109
# generation_hydro_pumped_storage_consumption         -0.188288
# generation_hydro_run-of-river_and_poundage          -0.286303
# generation_hydro_water_reservoir                    -0.288154
# generation_nuclear                                   0.087578
# generation_other                                    -0.359655
# generation_other_renewable                           0.613987
# generation_solar                                     0.000629
# generation_waste                                     1.000000
# generation_wind_onshore                             -0.183513
# total_load_actual                                    0.077163
# price_day_ahead                                      0.367999
# price_actual                                         0.168735
#
#                                              generation_wind_onshore  \
# generation_biomass                                         -0.068688
# generation_fossil_brown_coal_lignite                       -0.434212
# generation_fossil_gas                                      -0.397335
# generation_fossil_hard_coal                                -0.441781
# generation_fossil_oil                                      -0.051755
# generation_hydro_pumped_storage_consumption                 0.389139
# generation_hydro_run-of-river_and_poundage                  0.223203
# generation_hydro_water_reservoir                           -0.019419
# generation_nuclear                                          0.048472
# generation_other                                            0.047374
# generation_other_renewable                                 -0.138286
# generation_solar                                           -0.166606
# generation_waste                                           -0.183513
# generation_wind_onshore                                     1.000000
# total_load_actual                                           0.039788
# price_day_ahead                                            -0.424926
# price_actual                                               -0.220435
#
#                                              total_load_actual  \
# generation_biomass                                    0.083438
# generation_fossil_brown_coal_lignite                  0.280729
# generation_fossil_gas                                 0.548990
# generation_fossil_hard_coal                           0.396947
# generation_fossil_oil                                 0.496173
# generation_hydro_pumped_storage_consumption          -0.562769
# generation_hydro_run-of-river_and_poundage            0.118340
# generation_hydro_water_reservoir                      0.479253
# generation_nuclear                                    0.085803
# generation_other                                      0.100768
# generation_other_renewable                            0.180955
# generation_solar                                      0.395609
# generation_waste                                      0.077163
# generation_wind_onshore                               0.039788
# total_load_actual                                     1.000000
# price_day_ahead                                       0.474102
# price_actual                                          0.435573
#
#                                              price_day_ahead  price_actual
# generation_biomass                                  0.109236      0.142688
# generation_fossil_brown_coal_lignite                0.568156      0.363986
# generation_fossil_gas                               0.640891      0.461423
# generation_fossil_hard_coal                         0.671779      0.465648
# generation_fossil_oil                               0.292831      0.285021
# generation_hydro_pumped_storage_consumption        -0.600553     -0.426211
# generation_hydro_run-of-river_and_poundage         -0.294518     -0.136657
# generation_hydro_water_reservoir                   -0.017423      0.071830
# generation_nuclear                                 -0.043348     -0.052981
# generation_other                                    0.043971      0.099875
# generation_other_renewable                          0.427784      0.255544
# generation_solar                                    0.058049      0.098530
# generation_waste                                    0.367999      0.168735
# generation_wind_onshore                            -0.424926     -0.220435
# total_load_actual                                   0.474102      0.435573
# price_day_ahead                                     1.000000      0.732155
# price_actual                                        0.732155      1.000000

# %%
print(correlations1['price_actual'].sort_values(ascending=False))
# Out:
# price_actual                                   1.000000
# price_day_ahead                                0.732155
# generation_fossil_hard_coal                    0.465648
# generation_fossil_gas                          0.461423
# total_load_actual                              0.435573
# generation_fossil_brown_coal_lignite           0.363986
# generation_fossil_oil                          0.285021
# generation_other_renewable                     0.255544
# generation_waste                               0.168735
# generation_biomass                             0.142688
# generation_other                               0.099875
# generation_solar                               0.098530
# generation_hydro_water_reservoir               0.071830
# generation_nuclear                            -0.052981
# generation_hydro_run-of-river_and_poundage    -0.136657
# generation_wind_onshore                       -0.220435
# generation_hydro_pumped_storage_consumption   -0.426211
# Name: price_actual, dtype: float64

# %%
plt.figure(figsize=(22,18))
sns.heatmap(correlations1,annot=True)
# Out:
# <Axes: >

# %%
df_viz["time"]=pd.to_datetime(df_viz["time"], utc=True)
df_viz = df_viz.set_index('time')

# %%
#Set timeframe data for easier accessing
df_viz["year"]=df_viz.index.year
df_viz["month"]=df_viz.index.month
df_viz["month_name"]=df_viz.index.month_name()
df_viz["weekdays"] = df_viz.index.day_name()

# %%
plt.style.use("ggplot")
cols_plot = ["generation_wind_onshore","generation_solar","generation_fossil_hard_coal","generation_fossil_gas"]
axes=df_viz[cols_plot].loc["2018-01":"2018-12"].plot(marker="*", linestyle= "None", subplots= True, figsize=(11,9))
for ax in axes:
    ax.set_ylabel('Generation')

# %%
fig, axes=plt.subplots(3, 1, figsize=(11,9), sharex=True)
for name, ax in zip(["generation_wind_onshore","generation_solar","generation_fossil_hard_coal","generation_fossil_gas"], axes):
    sns.boxplot(data=df_viz, x='month_name', y=name, ax=ax )
    ax.set_ylabel('GWh')
    ax.set_xlabel("Months")
    ax.set_title(name)

# %%
monthly_mean=df_viz["price_actual"].resample("m").mean()
weekly_mean=df_viz["price_actual"].resample("w").mean()
daily_mean=df_viz["price_actual"].resample("d").mean()

# %%
plt.figure(figsize=[11,10])
plt.style.use("fivethirtyeight")
Price_plot = ["price_actual","price_day_ahead"]
fig,ax=plt.subplots(figsize=[10,8])
ax.plot(daily_mean.loc["2018-01":"2018-12"], marker="*", linewidth=0.5, label="Daily mean")
ax.plot(weekly_mean.loc["2018-01":"2018-12"], marker="o", linewidth=0.8, label="weekly average resample")
ax.plot(monthly_mean.loc["2018-01":"2018-12"], marker="+", linewidth=1.8, label="Monthly mean")
ax.set_ylabel("price")
ax.legend();

# %%
Price_plot = ["price_actual","price_day_ahead"]
df_viz[Price_plot].resample("w").mean().plot(kind="line",lw = 1.5)
plt.xlabel('Year')
plt.ylabel('Price/MWH')
# Out:
# Text(0, 0.5, 'Price/MWH')

# %%
# Figure Size
plt.figure(figsize=(8,5))

# Histogram to present distribution of target variable
sns.histplot(df_viz ,x='price_actual');

# %% [markdown]
# Data Exploration Findings:
#
# The target variable exhibits a normal distribution.
#
# Numerous columns display 0 values, particularly in relation to specific energy generation types.
#
# Identified significant correlations between certain columns.
#
# The dataset consists entirely of numeric data.

# %%
df_viz.to_csv('D:\programming project feb 2024\Spain Energy Dataset\df_viz.csv')
